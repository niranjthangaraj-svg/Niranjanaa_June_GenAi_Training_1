# %%
# !pip install -q google-generativeai
import google.generativeai as genai
from google.colab import userdata
genai.configure(api_key=userdata.get('Generative_Ai'))

def generate_email(recipient, purpose, tone):
  user_prompt = f"""
  Write a professional email.

  Recipient: {recipient}
  Purpose: {purpose}
  Tone: {tone}
  IMPORTANT:
  - At the end of the email, sign off using:
    Name: Niranjanaa
    Designation: Team Lead

  Include:
  - Subject line
  - Greeting
  - Body
  - Closing
  """

  model = genai.GenerativeModel(
      model_name='gemini-2.5-flash-lite',
      system_instruction="You are a professional email writer who writes clear and structured emails."
  )

  response = model.generate_content(
      user_prompt,
      generation_config={
          "temperature": 0.3,
          "max_output_tokens": 300,
      }
  )

  print(response.text)

recipient = input("Enter recipient (e.g., HR Manager, TCS): ")
purpose = input("Enter purpose (follow-up / thank-you / leave request): ")
tone = input("Enter tone (formal / professional / friendly): ")

generate_email(recipient, purpose, tone)
# Out:
# Enter recipient (e.g., HR Manager, TCS): Manager
# Enter purpose (follow-up / thank-you / leave request): Leave request
# Enter tone (formal / professional / friendly): Formal and polite
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 8572.35ms
# Subject: Leave Request - Niranjanaa
#
# Dear [Manager's Name],
#
# I am writing to formally request a leave of absence from [Start Date] to [End Date]. I would like to request [Number] days of leave.
#
# I will ensure that all my urgent tasks are completed before my departure and will make arrangements for my ongoing responsibilities to be covered during my absence. I will also be available via email for any critical matters, should the need arise.
#
# Thank you for considering my request.
#
# Sincerely,
#
# Niranjanaa
# Team Lead
