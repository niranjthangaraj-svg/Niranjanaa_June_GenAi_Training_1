# %%
# !pip install -q google-generativeai
import google.generativeai as genai
from google.colab import userdata


genai.configure(api_key=userdata.get('GENERATIVE_AI'))

knowledge_base = """
college: Greenfield Institute of Technology (GIT)

=== Admissions ===
{
    "question": "How do I apply for admission?",
    "answer": "Visit the official website at git.edu.in/admissions, fill out the online application form, upload required documents, and pay the application fee."
},
{
    "question": "What is the last date to apply?",
    "answer": "The application deadline for the current academic year is June 30. Late applications may be considered based on seat availability."
},
{
    "question": "What documents are required for admission?",
    "answer": "You need 10th and 12th mark sheets, transfer certificate, migration certificate, passport-size photos, Aadhaar card, and category certificate if applicable."
},
{
    "question": "Is there an entrance exam?",
    "answer": "Yes, admissions to engineering and science programs are based on JEE/NEET scores. Management programs use CAT/MAT scores."
},
{
    "question": "What are the eligibility criteria?",
    "answer": "Students must have passed 12th standard with a minimum of 60% marks in relevant subjects. SC/ST/OBC candidates get a 5% relaxation."
},

=== Fees & Scholarships ===
{
    "question": "What is the tuition fee?",
    "answer": "Tuition fees vary by program. B.Tech: Rs.85,000/year, BCA: Rs.45,000/year, MBA: Rs.1,20,000/year. Refer to the fee structure page for full details."
},
{
    "question": "Are scholarships available?",
    "answer": "Yes, merit scholarships, government scholarships (NSP), and need-based aid are available. Apply through the scholarship portal after enrollment."
},
{
    "question": "Can I pay fees in installments?",
    "answer": "Yes, fees can be paid in two installments per semester. Contact the accounts department for an installment plan."
},
{
    "question": "What payment methods are accepted?",
    "answer": "Fees can be paid via online transfer (NEFT/RTGS), UPI, credit/debit cards, or demand draft at the accounts office."
},

=== Courses & Programs ===
{
    "question": "What undergraduate programs are offered?",
    "answer": "We offer B.Tech (CSE, ECE, ME, CE), BCA, BBA, B.Sc (Physics, Chemistry, Maths), and B.Com programs."
},
{
    "question": "What postgraduate programs are offered?",
    "answer": "Postgraduate programs include M.Tech, MCA, MBA, and M.Sc in various specializations."
},
{
    "question": "Is there a PhD program?",
    "answer": "Yes, doctoral programs are available in Engineering, Management, and Sciences. Contact the research office at research@git.edu.in."
},
{
    "question": "Are there any diploma or certificate courses?",
    "answer": "Yes, short-term certificate courses in Python, Data Science, Cybersecurity, and Digital Marketing are offered through the continuing education center."
},

=== Campus & Facilities ===
{
    "question": "Is hostel accommodation available?",
    "answer": "Yes, separate hostels for boys and girls are available on campus. Apply through the hostel portal during admission."
},
{
    "question": "What sports facilities are available?",
    "answer": "The campus has cricket grounds, basketball and volleyball courts, a gymnasium, a swimming pool, and an indoor badminton court."
},
{
    "question": "Is there a library on campus?",
    "answer": "Yes, the central library has over 50,000 books, journals, e-resources, and 24/7 online access for enrolled students."
},
{
    "question": "Is Wi-Fi available on campus?",
    "answer": "Yes, the entire campus has high-speed Wi-Fi access available to all students and faculty."
},
{
    "question": "Is there a canteen or food court?",
    "answer": "Yes, the campus has a central food court and multiple canteens offering vegetarian and non-vegetarian meals."
},

=== Exams & Results ===
{
    "question": "How do I check my exam results?",
    "answer": "Log in to the student portal at portal.git.edu.in and navigate to Results under the Academics section."
},
{
    "question": "What is the passing criteria?",
    "answer": "Students must score a minimum of 40% in each subject and maintain an overall CGPA of 5.0 to pass a semester."
},
{
    "question": "Can I apply for revaluation?",
    "answer": "Yes, revaluation requests can be submitted through the exam portal within 15 days of result declaration, with a fee of Rs.500 per subject."
},
{
    "question": "What is the attendance requirement?",
    "answer": "A minimum of 75% attendance is mandatory to appear in semester examinations."
},

=== Placements ===
{
    "question": "Does the college have a placement cell?",
    "answer": "Yes, the Training & Placement cell facilitates campus recruitment. Students can register at placements.git.edu.in."
},
{
    "question": "What companies visit for campus placements?",
    "answer": "Top recruiters include TCS, Infosys, Wipro, Cognizant, Capgemini, Amazon, and Deloitte among others."
},
{
    "question": "What is the average placement package?",
    "answer": "The average CTC offered is Rs.5.2 LPA, with the highest package reaching Rs.18 LPA in the last placement season."
},

=== Contact ===
Contact: info@git.edu.in | Helpline: 1800-123-4567 (Mon-Sat, 9 AM - 5 PM)
Admissions Office: admissions@git.edu.in
Accounts / Fees: accounts@git.edu.in
"""

system_instruction = f"""
You are a friendly and helpful student support chatbot for Greenfield Institute of Technology (GIT).
Follow these rules strictly:

1. Answer ONLY using the information in the knowledge base below.
2. If a question is not covered in the knowledge base, reply exactly:
   "I'm sorry, I don't have that information. Please contact us at info@git.edu.in or call 1800-123-4567."
3. Be polite, concise, and helpful.
4. Do not make up information that is not in the knowledge base.

{knowledge_base}
"""
model = genai.GenerativeModel(
    model_name="gemini-2.5-flash-lite",
    system_instruction=system_instruction
)

chat = model.start_chat(history=[])

print(" GIT College Support Bot is ready! Type 'quit' to exit.\n")

while True:
    user_input = input("You: ").strip()

    if not user_input:
        continue

    if user_input.lower() in ["quit", "exit", "bye"]:
        print("Bot: Thank you for reaching out to GIT! Goodbye and best of luck! 🎓")
        break

    response = chat.send_message(user_input)
    print(f"Bot: {response.text}\n")
# Out:
#  GIT College Support Bot is ready! Type 'quit' to exit.
#
# You: HOW do i put admission
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash-lite:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1469.47ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_9382/3619727523.py in <cell line: 0>()
#     158         break
#     159
# --> 160     response = chat.send_message(user_input)
#     161     print(f"Bot: {response.text}\n")
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     576             )
#     577
# --> 578         response = self.model.generate_content(
#     579             contents=history,
#     580             generation_config=generation_config,
#
# ...
